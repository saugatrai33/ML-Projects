# %% [markdown]
# <a href="https://colab.research.google.com/github/saugatrai33/ML-Projects/blob/main/cnn_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Packages

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import os
import numpy as np
import glob
import shutil
import matplotlib.pyplot as plt

# %% [markdown]
# Import TensorFlow and Keras Layers

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Data Loading

# %%
_URL = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

zip_file = tf.keras.utils.get_file(origin=_URL, 
                                   fname="flower_photos.tgz", 
                                   extract=True)

base_dir = os.path.join(os.path.dirname(zip_file), 'flower_photos')
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 2s 0us/step
# 228827136/228813984 [==============================] - 2s 0us/step

# %% [markdown]
# The dataset we downloaded contains images of 5 types of flowers:
#
# Rose
# Daisy
# Dandelion
# Sunflowers
# Tulips

# %%
classes = ['roses', 'daisy', 'dandelion', 'sunflowers', 'tulips'] # 5 classes

# %% [markdown]
# train and val directory added to base directory flower_photos

# %%
for cl in classes:
  img_path = os.path.join(base_dir, cl)
  images = glob.glob(img_path + '/*.jpg')
  print("{}: {} Images".format(cl, len(images)))
  num_train = int(round(len(images)*0.8))
  train, val = images[:num_train], images[num_train:]

  for t in train:
    if not os.path.exists(os.path.join(base_dir, 'train', cl)):
      os.makedirs(os.path.join(base_dir, 'train', cl))
    shutil.move(t, os.path.join(base_dir, 'train', cl))

  for v in val:
    if not os.path.exists(os.path.join(base_dir, 'val', cl)):
      os.makedirs(os.path.join(base_dir, 'val', cl))
    shutil.move(v, os.path.join(base_dir, 'val', cl))
# Out:
# roses: 641 Images
# daisy: 633 Images
# dandelion: 898 Images
# sunflowers: 699 Images
# tulips: 799 Images

# %%
round(len(images)*0.8)
# Out:
# 639

# %%
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')

# %% [markdown]
# # Data Augmentation
#
# ## Experiment with Various Image Transformations
#
# Set Batch and Image Size

# %% [markdown]
# Set Batch and Image Size

# %%
batch_size = 100
IMG_SHAPE = 150

# %% [markdown]
#  Random Horizontal Flip

# %%
image_gen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)

train_data_gen = image_gen.flow_from_directory(
                                                batch_size=batch_size, 
                                                directory=train_dir, 
                                                shuffle=True, 
                                                target_size=(IMG_SHAPE,IMG_SHAPE)
                                                )
# Out:
# Found 2935 images belonging to 5 classes.

# %% [markdown]
# Show output image with 1 row 5 column

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()
    
    
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# Random Rotation

# %%
image_gen = ImageDataGenerator(rescale=1./255, rotation_range=45)

train_data_gen = image_gen.flow_from_directory(batch_size=batch_size, 
                                               directory=train_dir, 
                                               shuffle=True, 
                                               target_size=(IMG_SHAPE, IMG_SHAPE))
# Out:
# Found 2935 images belonging to 5 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# Random Zoom

# %%
image_gen = ImageDataGenerator(rescale=1./255, zoom_range=0.5)

train_data_gen = image_gen.flow_from_directory(
                                                batch_size=batch_size, 
                                                directory=train_dir, 
                                                shuffle=True, 
                                                target_size=(IMG_SHAPE, IMG_SHAPE)
                                                )
# Out:
# Found 2935 images belonging to 5 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# ### Put It All Together
#
# random 45 degree rotation
# random zoom of up to 50%
# random horizontal flip
# width shift of 0.15
# height shfit of 0.15

# %%
image_gen_train = ImageDataGenerator(
                    rescale=1./255, 
                    rotation_range=45, 
                    width_shift_range=.15, 
                    height_shift_range=.15, 
                    horizontal_flip=True, 
                    zoom_range=0.5
                    )


train_data_gen = image_gen_train.flow_from_directory(
                                                batch_size=batch_size, 
                                                directory=train_dir, 
                                                shuffle=True, 
                                                target_size=(IMG_SHAPE,IMG_SHAPE),
                                                class_mode='sparse'
                                                )
# Out:
# Found 2935 images belonging to 5 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# ### Data Generator for the Validation Set

# %%
image_gen_val = ImageDataGenerator(rescale=1./255)

val_data_gen = image_gen_val.flow_from_directory(batch_size=batch_size, 
                                                 directory=val_dir, 
                                                 target_size=(IMG_SHAPE, IMG_SHAPE),
                                                 class_mode='sparse')
# Out:
# Found 735 images belonging to 5 classes.

# %% [markdown]
# # Create the CNN

# %%
model = Sequential()

model.add(Conv2D(16, 3, padding='same', activation='relu', input_shape=(IMG_SHAPE,IMG_SHAPE, 3))) 
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))

model.add(Dropout(0.2))
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# # Compile the Model

# %%
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # Train the Model

# %%
epochs = 80

history = model.fit_generator(
  train_data_gen,
    steps_per_epoch=int(np.ceil(train_data_gen.n / float(batch_size))),
    epochs=epochs,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(val_data_gen.n / float(batch_size)))
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/80
# 30/30 [==============================] - 93s 3s/step - loss: 1.5141 - accuracy: 0.3203 - val_loss: 1.1798 - val_accuracy: 0.4952
# Epoch 2/80
# 30/30 [==============================] - 92s 3s/step - loss: 1.2012 - accuracy: 0.4835 - val_loss: 1.0403 - val_accuracy: 0.5646
# Epoch 3/80
# 30/30 [==============================] - 93s 3s/step - loss: 1.0701 - accuracy: 0.5670 - val_loss: 1.0550 - val_accuracy: 0.5673
# Epoch 4/80
# 30/30 [==============================] - 93s 3s/step - loss: 1.0291 - accuracy: 0.5877 - val_loss: 0.9952 - val_accuracy: 0.5959
# Epoch 5/80
# 30/30 [==============================] - 93s 3s/step - loss: 0.9683 - accuracy: 0.6177 - val_loss: 0.8859 - val_accuracy: 0.6435
# Epoch 6/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.9328 - accuracy: 0.6293 - val_loss: 0.9461 - val_accuracy: 0.6218
# Epoch 7/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.8859 - accuracy: 0.6593 - val_loss: 0.8433 - val_accuracy: 0.6395
# Epoch 8/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.8766 - accuracy: 0.6579 - val_loss: 0.8317 - val_accuracy: 0.6680
# Epoch 9/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.8813 - accuracy: 0.6545 - val_loss: 0.7687 - val_accuracy: 0.6816
# Epoch 10/80
# 30/30 [==============================] - 93s 3s/step - loss: 0.8210 - accuracy: 0.6726 - val_loss: 0.7690 - val_accuracy: 0.6803
# Epoch 11/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.8129 - accuracy: 0.6838 - val_loss: 0.7691 - val_accuracy: 0.6939
# Epoch 12/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.7932 - accuracy: 0.6971 - val_loss: 0.7349 - val_accuracy: 0.7088
# Epoch 13/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.7805 - accuracy: 0.6985 - val_loss: 0.7249 - val_accuracy: 0.7088
# Epoch 14/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.7611 - accuracy: 0.7049 - val_loss: 0.6842 - val_accuracy: 0.7293
# Epoch 15/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.7546 - accuracy: 0.7077 - val_loss: 0.7150 - val_accuracy: 0.7088
# Epoch 16/80
# 30/30 [==============================] - 93s 3s/step - loss: 0.7388 - accuracy: 0.7083 - val_loss: 0.6874 - val_accuracy: 0.7265
# Epoch 17/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.7134 - accuracy: 0.7213 - val_loss: 0.6773 - val_accuracy: 0.7333
# Epoch 18/80
# 30/30 [==============================] - 93s 3s/step - loss: 0.7358 - accuracy: 0.7145 - val_loss: 0.7487 - val_accuracy: 0.7088
# Epoch 19/80
# 30/30 [==============================] - 93s 3s/step - loss: 0.7174 - accuracy: 0.7216 - val_loss: 0.6430 - val_accuracy: 0.7306
# Epoch 20/80
# 30/30 [==============================] - 93s 3s/step - loss: 0.6866 - accuracy: 0.7288 - val_loss: 0.6715 - val_accuracy: 0.7388
# Epoch 21/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.6675 - accuracy: 0.7414 - val_loss: 0.6850 - val_accuracy: 0.7401
# Epoch 22/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.6740 - accuracy: 0.7349 - val_loss: 0.6609 - val_accuracy: 0.7374
# Epoch 23/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.6559 - accuracy: 0.7438 - val_loss: 0.6512 - val_accuracy: 0.7374
# Epoch 24/80
# 30/30 [==============================] - 93s 3s/step - loss: 0.6423 - accuracy: 0.7503 - val_loss: 0.6575 - val_accuracy: 0.7333
# Epoch 25/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.6365 - accuracy: 0.7567 - val_loss: 0.6341 - val_accuracy: 0.7524
# Epoch 26/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.6294 - accuracy: 0.7543 - val_loss: 0.6723 - val_accuracy: 0.7456
# Epoch 27/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.6381 - accuracy: 0.7540 - val_loss: 0.6531 - val_accuracy: 0.7306
# Epoch 28/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.6141 - accuracy: 0.7659 - val_loss: 0.6248 - val_accuracy: 0.7537
# Epoch 29/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.6019 - accuracy: 0.7704 - val_loss: 0.7181 - val_accuracy: 0.7211
# Epoch 30/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.5960 - accuracy: 0.7765 - val_loss: 0.7113 - val_accuracy: 0.7401
# Epoch 31/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.5982 - accuracy: 0.7738 - val_loss: 0.6343 - val_accuracy: 0.7456
# Epoch 32/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.6118 - accuracy: 0.7612 - val_loss: 0.6826 - val_accuracy: 0.7361
# Epoch 33/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.5807 - accuracy: 0.7857 - val_loss: 0.6065 - val_accuracy: 0.7551
# Epoch 34/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.5577 - accuracy: 0.7843 - val_loss: 0.6254 - val_accuracy: 0.7605
# Epoch 35/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.5403 - accuracy: 0.7867 - val_loss: 0.6382 - val_accuracy: 0.7537
# Epoch 36/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.5673 - accuracy: 0.7884 - val_loss: 0.6265 - val_accuracy: 0.7537
# Epoch 37/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.5580 - accuracy: 0.7806 - val_loss: 0.5984 - val_accuracy: 0.7483
# Epoch 38/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.5427 - accuracy: 0.7871 - val_loss: 0.6169 - val_accuracy: 0.7524
# Epoch 39/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.5462 - accuracy: 0.7901 - val_loss: 0.6297 - val_accuracy: 0.7537
# Epoch 40/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.5237 - accuracy: 0.8000 - val_loss: 0.5868 - val_accuracy: 0.7687
# Epoch 41/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.5398 - accuracy: 0.7911 - val_loss: 0.6671 - val_accuracy: 0.7469
# Epoch 42/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.5542 - accuracy: 0.7874 - val_loss: 0.6701 - val_accuracy: 0.7429
# Epoch 43/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.5351 - accuracy: 0.7959 - val_loss: 0.6034 - val_accuracy: 0.7673
# Epoch 44/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.5310 - accuracy: 0.8031 - val_loss: 0.6781 - val_accuracy: 0.7483
# Epoch 45/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4917 - accuracy: 0.8184 - val_loss: 0.5921 - val_accuracy: 0.7687
# Epoch 46/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.4969 - accuracy: 0.8112 - val_loss: 0.6026 - val_accuracy: 0.7524
# Epoch 47/80
# 30/30 [==============================] - 93s 3s/step - loss: 0.4820 - accuracy: 0.8208 - val_loss: 0.6264 - val_accuracy: 0.7483
# Epoch 48/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.5045 - accuracy: 0.8089 - val_loss: 0.6002 - val_accuracy: 0.7728
# Epoch 49/80
# 30/30 [==============================] - 90s 3s/step - loss: 0.4738 - accuracy: 0.8119 - val_loss: 0.6459 - val_accuracy: 0.7605
# Epoch 50/80
# 30/30 [==============================] - 90s 3s/step - loss: 0.4702 - accuracy: 0.8194 - val_loss: 0.6181 - val_accuracy: 0.7741
# Epoch 51/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4709 - accuracy: 0.8228 - val_loss: 0.6181 - val_accuracy: 0.7755
# Epoch 52/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.4535 - accuracy: 0.8310 - val_loss: 0.6327 - val_accuracy: 0.7660
# Epoch 53/80
# 30/30 [==============================] - 93s 3s/step - loss: 0.4849 - accuracy: 0.8133 - val_loss: 0.6157 - val_accuracy: 0.7810
# Epoch 54/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.4553 - accuracy: 0.8293 - val_loss: 0.7234 - val_accuracy: 0.7497
# Epoch 55/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.4808 - accuracy: 0.8143 - val_loss: 0.6888 - val_accuracy: 0.7605
# Epoch 56/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.4545 - accuracy: 0.8235 - val_loss: 0.6710 - val_accuracy: 0.7619
# Epoch 57/80
# 30/30 [==============================] - 93s 3s/step - loss: 0.4756 - accuracy: 0.8102 - val_loss: 0.7105 - val_accuracy: 0.7605
# Epoch 58/80
# 30/30 [==============================] - 93s 3s/step - loss: 0.4567 - accuracy: 0.8235 - val_loss: 0.6184 - val_accuracy: 0.7687
# Epoch 59/80
# 30/30 [==============================] - 93s 3s/step - loss: 0.4259 - accuracy: 0.8450 - val_loss: 0.6584 - val_accuracy: 0.7673
# Epoch 60/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.4771 - accuracy: 0.8119 - val_loss: 0.6581 - val_accuracy: 0.7714
# Epoch 61/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4257 - accuracy: 0.8446 - val_loss: 0.6338 - val_accuracy: 0.7660
# Epoch 62/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4131 - accuracy: 0.8416 - val_loss: 0.6091 - val_accuracy: 0.7687
# Epoch 63/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4409 - accuracy: 0.8303 - val_loss: 0.6823 - val_accuracy: 0.7592
# Epoch 64/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4297 - accuracy: 0.8392 - val_loss: 0.6043 - val_accuracy: 0.7850
# Epoch 65/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.4090 - accuracy: 0.8440 - val_loss: 0.6513 - val_accuracy: 0.7605
# Epoch 66/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4128 - accuracy: 0.8405 - val_loss: 0.6303 - val_accuracy: 0.7850
# Epoch 67/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.3863 - accuracy: 0.8545 - val_loss: 0.5859 - val_accuracy: 0.7891
# Epoch 68/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.3938 - accuracy: 0.8518 - val_loss: 0.6697 - val_accuracy: 0.7510
# Epoch 69/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.4225 - accuracy: 0.8375 - val_loss: 0.6530 - val_accuracy: 0.7646
# Epoch 70/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.3892 - accuracy: 0.8600 - val_loss: 0.5940 - val_accuracy: 0.7687
# Epoch 71/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.3923 - accuracy: 0.8457 - val_loss: 0.7006 - val_accuracy: 0.7687
# Epoch 72/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.3947 - accuracy: 0.8559 - val_loss: 0.6577 - val_accuracy: 0.7728
# Epoch 73/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.4267 - accuracy: 0.8365 - val_loss: 0.6016 - val_accuracy: 0.7810
# Epoch 74/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.3596 - accuracy: 0.8692 - val_loss: 0.6092 - val_accuracy: 0.7810
# Epoch 75/80
# 30/30 [==============================] - 90s 3s/step - loss: 0.3520 - accuracy: 0.8726 - val_loss: 0.7207 - val_accuracy: 0.7551
# Epoch 76/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.3669 - accuracy: 0.8664 - val_loss: 0.6105 - val_accuracy: 0.7973
# Epoch 77/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.3711 - accuracy: 0.8569 - val_loss: 0.6020 - val_accuracy: 0.7850
# Epoch 78/80
# 30/30 [==============================] - 92s 3s/step - loss: 0.3652 - accuracy: 0.8569 - val_loss: 0.6673 - val_accuracy: 0.7755
# Epoch 79/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.3575 - accuracy: 0.8668 - val_loss: 0.6230 - val_accuracy: 0.7850
# Epoch 80/80
# 30/30 [==============================] - 90s 3s/step - loss: 0.3665 - accuracy: 0.8637 - val_loss: 0.6193 - val_accuracy: 0.7796

# %% [markdown]
# # Plot Training and Validation Graphs

# %%
# acc = history.history['acc']
# val_acc = history.history['val_acc']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
# plot(epochs_range, acc, label='Training Accuracy')
#plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# No handles with labels found to put in legend.
